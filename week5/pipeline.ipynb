# %%
# Install the Ultralytics library for YOLOv8
# !pip install ultralytics

from ultralytics import YOLO
import os

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1IYgZUfnYyxI1d9AVmui")
project = rf.workspace("mansha-ulhaq-s-workspace").project("helmet_detection-kmc53")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 107.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to helmet_detection-1 in yolov8:: 100%|██████████| 2851/2851 [00:00<00:00, 6945.80it/s]

# %%
from ultralytics import YOLO

# Load the nano model (lightweight for safety detection)
model = YOLO('yolov8n.pt')

# %%
# Train the model for 50 epochs
results = model.train(
    data='/content/helmet_detection-1/data.yaml',
    epochs=50,
    imgsz=640,
    plots=True
)
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
